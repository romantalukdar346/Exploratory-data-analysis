# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
dm= pd.read_csv('C:\\Users\\KIIT\\OneDrive\\Desktop\\code 1\\Machine_Learning\\matches.csv')

# %%
dd= pd.read_csv('C:\\Users\\KIIT\\OneDrive\\Desktop\\code 1\\Machine_Learning\\deliveries.csv')

# %%
dm.sample(5)
# Out:
#       id  season           city        date                team1  \
# 475  476    2014      Abu Dhabi  2014-04-29     Rajasthan Royals
# 569  570    2015         Mumbai  2015-05-16     Rajasthan Royals
# 510  511    2014        Kolkata  2014-05-24  Sunrisers Hyderabad
# 536  537    2015  Visakhapatnam  2015-04-22  Sunrisers Hyderabad
# 38    39    2017          Delhi  2017-05-02  Sunrisers Hyderabad
#
#                      team2            toss_winner toss_decision  result  \
# 475  Kolkata Knight Riders       Rajasthan Royals           bat     tie
# 569  Kolkata Knight Riders       Rajasthan Royals           bat  normal
# 510  Kolkata Knight Riders  Kolkata Knight Riders         field  normal
# 536  Kolkata Knight Riders  Kolkata Knight Riders         field  normal
# 38        Delhi Daredevils       Delhi Daredevils         field  normal
#
#      dl_applied                 winner  win_by_runs  win_by_wickets  \
# 475           0       Rajasthan Royals            0               0
# ...

# %%
dd.sample(5)
# Out:
#         match_id  inning             batting_team  \
# 17969         77       1          Deccan Chargers
# 108459       458       1    Kolkata Knight Riders
# 42518        181       1          Kings XI Punjab
# 142007       601       1  Rising Pune Supergiants
# 139733       591       1            Gujarat Lions
#
#                        bowling_team  over  ball    batsman non_striker  \
# 17969               Kings XI Punjab    14     6  SB Bangar   RG Sharma
# 108459               Mumbai Indians     8     3  MK Pandey   JH Kallis
# 42518   Royal Challengers Bangalore    13     1   MS Bisla   RS Bopara
# 142007                Gujarat Lions     3     6  SPD Smith   AM Rahane
# 139733          Sunrisers Hyderabad    18     5   SK Raina     AD Nath
#
#                  bowler  is_super_over  ...  bye_runs  legbye_runs  \
# 17969   Gagandeep Singh              0  ...         0            0
# 108459          PP Ojha              0  ...         0            0
# ...

# %%
dm.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
dd.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
dd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150460 entries, 0 to 150459
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          150460 non-null  int64
#  1   inning            150460 non-null  int64
#  2   batting_team      150460 non-null  object
#  3   bowling_team      150460 non-null  object
#  4   over              150460 non-null  int64
#  5   ball              150460 non-null  int64
#  6   batsman           150460 non-null  object
#  7   non_striker       150460 non-null  object
#  8   bowler            150460 non-null  object
#  9   is_super_over     150460 non-null  int64
#  10  wide_runs         150460 non-null  int64
#  11  bye_runs          150460 non-null  int64
#  12  legbye_runs       150460 non-null  int64
#  13  noball_runs       150460 non-null  int64
#  14  penalty_runs      150460 non-null  int64
#  15  batsman_runs      150460 non-null  int64
# ...

# %%
dm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    object
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
#  16  umpire2          635 non-null    object
# ...

# %%
dd.describe()
# Out:
#             match_id         inning           over           ball  \
# count  150460.000000  150460.000000  150460.000000  150460.000000
# mean      318.281317       1.482188      10.142649       3.616483
# std       182.955531       0.501768       5.674338       1.807698
# min         1.000000       1.000000       1.000000       1.000000
# 25%       161.000000       1.000000       5.000000       2.000000
# 50%       319.000000       1.000000      10.000000       4.000000
# 75%       476.000000       2.000000      15.000000       5.000000
# max       636.000000       4.000000      20.000000       9.000000
#
#        is_super_over      wide_runs       bye_runs    legbye_runs  \
# count  150460.000000  150460.000000  150460.000000  150460.000000
# mean        0.000538       0.037498       0.004885       0.022232
# std         0.023196       0.257398       0.114234       0.200104
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
dm.describe()
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  636.000000   636.000000  636.000000   636.000000      636.000000
# mean   318.500000  2012.490566    0.025157    13.682390        3.372642
# std    183.741666     2.773026    0.156726    23.908877        3.420338
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    159.750000  2010.000000    0.000000     0.000000        0.000000
# 50%    318.500000  2012.000000    0.000000     0.000000        4.000000
# 75%    477.250000  2015.000000    0.000000    20.000000        7.000000
# max    636.000000  2017.000000    1.000000   146.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
dd.isnull().sum()
# Out:
# match_id                 0
# inning                   0
# batting_team             0
# bowling_team             0
# over                     0
# ball                     0
# batsman                  0
# non_striker              0
# bowler                   0
# is_super_over            0
# wide_runs                0
# bye_runs                 0
# legbye_runs              0
# noball_runs              0
# penalty_runs             0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# player_dismissed    143022
# dismissal_kind      143022
# fielder             145091
# dtype: int64

# %%
dm.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               3
# win_by_runs          0
# win_by_wickets       0
# player_of_match      3
# venue                0
# umpire1              1
# umpire2              1
# umpire3            636
# dtype: int64

# %%
dm.shape
# Out:
# (636, 18)

# %%
dd.shape
# Out:
# (150460, 21)

# %%
dd.duplicated().sum()
# Out:
# 1

# %%
dm.duplicated().sum()
# Out:
# 0

# %%
sns.heatmap(dd.corr())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(dm.corr())
# Out:
# <AxesSubplot:>

# %%
dm.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
dm.drop(columns=['umpire3'],inplace=True)

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(12,8))
sns.countplot(y=dm['city'],order=dm['city'].value_counts().index)
# Out:
# <AxesSubplot:xlabel='count', ylabel='city'>

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(12,8))
sns.countplot(y=dm['venue'],order=dm['venue'].value_counts().index)
# Out:
# <AxesSubplot:xlabel='count', ylabel='venue'>

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(12,8))
sns.countplot(y=dm['season'],order=dm['season'].value_counts().index)
# Out:
# <AxesSubplot:xlabel='count', ylabel='season'>

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(12,8))
sns.countplot(dm['toss_decision'],order=dm['toss_decision'].value_counts().index)
# Out:
# C:\Users\KIIT\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='toss_decision', ylabel='count'>

# %%
co=dm.pivot_table(index='toss_decision',columns='season',aggfunc='count',values='city')

# %%
sns.heatmap(co)
# Out:
# <AxesSubplot:xlabel='season', ylabel='toss_decision'>

# %%
co
# Out:
# season         2008  2009  2010  2011  2012  2013  2014  2015  2016  2017
# toss_decision
# bat              26    35    39    25    37    45    16    25    11    11
# field            32    22    21    48    37    31    37    34    49    48

# %%
dm[['season','player_of_match']].value_counts().sort_values(ascending=False)
# Out:
# season  player_of_match
# 2011    CH Gayle           6
# 2012    CH Gayle           5
# 2016    V Kohli            5
# 2008    SE Marsh           5
# 2013    MEK Hussey         5
#                           ..
# 2015    SL Malinga         1
#         SE Marsh           1
#         DJ Bravo           1
#         DJ Hooda           1
# 2017    Yuvraj Singh       1
# Length: 435, dtype: int64

# %%
dm.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
sns.countplot(y=dm['toss_winner'], order=dm['toss_winner'].value_counts().index)
# Out:
# <AxesSubplot:xlabel='count', ylabel='toss_winner'>

# %%
sns.countplot(y=dm['winner'], order=dm['winner'].value_counts().index)
# Out:
# <AxesSubplot:xlabel='count', ylabel='winner'>

# %%
same=dm[dm['toss_winner']== dm['winner']]

sns.countplot(y=same['toss_winner'], order=same['toss_winner'].value_counts().index)
plt.title('Winning the toss winning the match')
# Out:
# Text(0.5, 1.0, 'Winning the toss winning the match')

# %%
diff=dm[dm['toss_winner']!= dm['winner']]

sns.countplot(y=diff['toss_winner'], order=diff['toss_winner'].value_counts().index)
plt.title('Losing the toss losing the match')
# Out:
# Text(0.5, 1.0, 'Losing the toss losing the match')

# %%
diff.shape
# Out:
# (311, 17)

# %%
same['toss_winner'].unique()
# Out:
# array(['Rising Pune Supergiant', 'Kolkata Knight Riders',
#        'Kings XI Punjab', 'Royal Challengers Bangalore',
#        'Sunrisers Hyderabad', 'Mumbai Indians', 'Gujarat Lions',
#        'Delhi Daredevils', 'Chennai Super Kings', 'Rajasthan Royals',
#        'Deccan Chargers', 'Kochi Tuskers Kerala', 'Pune Warriors',
#        'Rising Pune Supergiants'], dtype=object)

# %%
dm['toss_winner'].value_counts()
# Out:
# Mumbai Indians                 85
# Kolkata Knight Riders          78
# Delhi Daredevils               72
# Royal Challengers Bangalore    70
# Kings XI Punjab                68
# Chennai Super Kings            66
# Rajasthan Royals               63
# Deccan Chargers                43
# Sunrisers Hyderabad            35
# Pune Warriors                  20
# Gujarat Lions                  15
# Kochi Tuskers Kerala            8
# Rising Pune Supergiants         7
# Rising Pune Supergiant          6
# Name: toss_winner, dtype: int64

# %%
s=dm[dm['toss_winner']=='Mumbai Indians']['winner'] != 'Mumbai Indians'

# %%
total=dm['toss_winner'].value_counts()
num=[]
for i in range(len(total)):
    num.append(total[i])

num
# Out:
# [85, 78, 72, 70, 68, 66, 63, 43, 35, 20, 15, 8, 7, 6]

# %%
 dm[(dm['toss_winner'] == 'Mumbai Indians') & (dm['winner'] != 'Mumbai Indians')].shape
# Out:
# (37, 17)

# %%
win=[]
lose=[]
team=dm['toss_winner'].value_counts().index
for i in team:
    win.append(dm[(dm['toss_winner'] == i) & (dm['winner'] == i)].shape[0])
    lose.append(dm[(dm['toss_winner'] == i) & (dm['winner'] != i)].shape[0])

# %%
win
# Out:
# [48, 44, 33, 35, 28, 42, 34, 19, 17, 3, 10, 4, 3, 5]

# %%
lose
# Out:
# [37, 34, 39, 35, 40, 24, 29, 24, 18, 17, 5, 4, 4, 1]

# %%
winpct=[]
losepct=[]
for i in range(len(total)):
    winpct.append(round((win[i]/num[i])*100,2))
    losepct.append(round((lose[i]/num[i])*100,2))

# %%
winpct
# Out:
# [56.47,
#  56.41,
#  45.83,
#  50.0,
#  41.18,
#  63.64,
#  53.97,
#  44.19,
#  48.57,
#  15.0,
#  66.67,
#  50.0,
#  42.86,
#  83.33]

# %%
losepct
# Out:
# [43.53,
#  43.59,
#  54.17,
#  50.0,
#  58.82,
#  36.36,
#  46.03,
#  55.81,
#  51.43,
#  85.0,
#  33.33,
#  50.0,
#  57.14,
#  16.67]

# %%
sns.barplot(winpct,total.index);
plt.show()
# Out:
# C:\Users\KIIT\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.barplot(dm['toss_winner']==dm['winner'],dm['winner'])
# Out:
# C:\Users\KIIT\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:ylabel='winner'>

# %%
dd
# Out:
#         match_id  inning                 batting_team  \
# 0              1       1          Sunrisers Hyderabad
# 1              1       1          Sunrisers Hyderabad
# 2              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 4              1       1          Sunrisers Hyderabad
# ...          ...     ...                          ...
# 150455       636       2  Royal Challengers Bangalore
# 150456       636       2  Royal Challengers Bangalore
# 150457       636       2  Royal Challengers Bangalore
# 150458       636       2  Royal Challengers Bangalore
# 150459       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball        batsman    non_striker  \
# 0       Royal Challengers Bangalore     1     1      DA Warner       S Dhawan
# 1       Royal Challengers Bangalore     1     2      DA Warner       S Dhawan
# 2       Royal Challengers Bangalore     1     3      DA Warner       S Dhawan
# ...

# %%
dd.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
dd.shape
# Out:
# (150460, 21)

# %%
dd['total_runs'].sum()
# Out:
# 194314

# %%
sns.distplot(dd.groupby(by='batsman')['total_runs'].sum())
# Out:
# C:\Users\KIIT\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total_runs', ylabel='Density'>

# %%
batsman_runs=dd.groupby(by='batsman')['batsman_runs'].sum().sort_values(ascending=False)

# %%
batsman_runs.shape
# Out:
# (461,)

# %%
plt.figure(figsize=(12,8))
sns.barplot(y=batsman_runs.head(30).index,x=batsman_runs.head(30))
# Out:
# <AxesSubplot:xlabel='batsman_runs', ylabel='batsman'>

# %%
plt.boxplot(batsman_runs.head(5));

# %%
batsman_runs.mean()
# Out:
# 398.9783080260304

# %%
batsman_runs.std()
# Out:
# 785.4433582974996

# %%
run=dd.groupby(by='batsman')['total_runs'].sum()
run=run.values

# %%
import random
mean=[]
n=50
for j in range(1000):
    x=np.random.choice(run,size=n)
    mean.append(x.mean())

# %%
len(mean)
# Out:
# 1000

# %%
new=np.array(mean)
len(new)
# Out:
# 1000

# %%
new.mean()
# Out:
# 422.29414

# %%
new.std()
# Out:
# 115.65351283752864

# %%
sns.distplot(new)
# Out:
# C:\Users\KIIT\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
run_list.values
# Out:
# array([ 288,    4,   58,   25,   72,   42,  374,   37,   20,   49,    3,
#        1028,    4,    5,   78,   12,  235,   11,  193,   44,   30,  130,
#        3621,  126, 2215,   20,  190,   81,  765,   20,  615,    7,   10,
#          56, 1705,   56,  416,  722, 3191,   38,    7,   35,   90,  365,
#          12,  634,    6,  204,   52, 2518,   42,    0,   66,   89,    9,
#          36,  409,   80,  292,  164,    4,  133,   36,    6,  324,    3,
#        2965,  132,    5,  135,    1,   18, 1477,  205,   23,   44,   32,
#         190,   22,   35,    0,  130,   27,  410,  421, 3914,  456,  542,
#         101,    4,    8,   19,    8, 1000,  199,  105,   46,    4,    4,
#          33,  136,   10, 1647, 4213,   12,  321,  401,   24,  187, 1335,
#         119,  386, 1384,  102,    1,   53,  317,   14,  141,    6,   13,
#           4,    1, 1929,   21, 2515,   97,   20,  439,   13,  178,  907,
#          29,   14, 1343,    4,  207, 4388,   22,  800,    4,  299,  692,
# ...

# %%
run.mean()
# Out:
# 421.5054229934924

# %%
new.mean()
# Out:
# 422.29414

# %%
run.var()/50
# Out:
# 13614.62521633156

# %%
new.var()
# Out:
# 13375.7350316604

# %%
run.std()/50
# Out:
# 16.501287959630037

# %%
new.std()/7.2
# Out:
# 16.062987894101198

# %%
dd.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
bwdts=dd.groupby(by=['bowler']).sum()
bwdts
# Out:
#                 match_id  inning   over  ball  is_super_over  wide_runs  \
# bowler
# A Ashish Reddy    109528     442   3805   962              0          8
# A Chandila         92700     348   1314   819              0          0
# A Choudhary         3146     164   1002   402              0          6
# A Flintoff          8028      84    846   231              0          0
# A Kumble          154701    1376  10669  3488              0         26
# ...                  ...     ...    ...   ...            ...        ...
# YA Abdulla         31818     337   2307   820              0         12
# YK Pathan         285413    1651  10481  4210              0         43
# YS Chahal         523722    1827  13001  4358              0         34
# Yuvraj Singh      276949    1296  10391  3085              0         11
# Z Khan            668455    3312  18966  8217              0         89
#
#                 bye_runs  legbye_runs  noball_runs  penalty_runs  \
# bowler
# ...

# %%
sns.distplot(bwdts['total_runs'])
# Out:
# C:\Users\KIIT\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total_runs', ylabel='Density'>

# %%
bwdts.where(bwdts['ball']>(500)).sort_values(by=['ball'],ascending=True).dropna()
# Out:
#                   match_id  inning     over     ball  is_super_over  \
# bowler
# K Rabada            4901.0   171.0   1292.0    503.0            0.0
# Mohammed Siraj      5139.0   237.0   1343.0    504.0            0.0
# S Ladda            35665.0   166.0   1588.0    504.0            0.0
# RR Raje            16082.0   211.0   1802.0    515.0            0.0
# R Sathish          51402.0   246.0   1753.0    520.0            0.0
# ...                    ...     ...      ...      ...            ...
# PP Chawla         826798.0  3717.0  29584.0   9168.0            0.0
# P Kumar           845901.0  3888.0  20159.0   9614.0            0.0
# A Mishra          888191.0  4171.0  31208.0   9679.0            0.0
# SL Malinga        847729.0  4055.0  29741.0   9881.0            0.0
# Harbhajan Singh  1044105.0  4574.0  29271.0  10708.0            0.0
#
#                  wide_runs  bye_runs  legbye_runs  noball_runs  penalty_runs  \
# bowler
# ...

# %%
eco_rate= (bwdts['total_runs']/(bwdts['ball']/6))
eco_rate
# Out:
# bowler
# A Ashish Reddy    2.494802
# A Chandila        1.794872
# A Choudhary       2.149254
# A Flintoff        2.753247
# A Kumble          1.873280
#                     ...
# YA Abdulla        2.275610
# YK Pathan         2.025178
# YS Chahal         2.202845
# Yuvraj Singh      2.077147
# Z Khan            2.088353
# Length: 356, dtype: float64

# %%
sns.histplot(eco_rate)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
bwdts[bwdts['ball']> 5000].shape
# Out:
# (30, 13)

# %%
sns.distplot(eco_rate)
# Out:
# C:\Users\KIIT\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
balls_1000= bwdts['ball']>5000

# %%
balls_1000= bwdts['ball']>5000
sns.distplot(bwdts[balls_1000]['noball_runs'],label='NO ball')
sns.distplot(bwdts[balls_1000]['legbye_runs'],label='Legby')
sns.distplot(bwdts[balls_1000]['wide_runs'],label='Wide')
plt.legend()
plt.show();
# Out:
# C:\Users\KIIT\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\KIIT\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
bwdts
# Out:
#                 match_id  inning   over  ball  is_super_over  wide_runs  \
# bowler
# A Ashish Reddy    109528     442   3805   962              0          8
# A Chandila         92700     348   1314   819              0          0
# A Choudhary         3146     164   1002   402              0          6
# A Flintoff          8028      84    846   231              0          0
# A Kumble          154701    1376  10669  3488              0         26
# ...                  ...     ...    ...   ...            ...        ...
# YA Abdulla         31818     337   2307   820              0         12
# YK Pathan         285413    1651  10481  4210              0         43
# YS Chahal         523722    1827  13001  4358              0         34
# Yuvraj Singh      276949    1296  10391  3085              0         11
# Z Khan            668455    3312  18966  8217              0         89
#
#                 bye_runs  legbye_runs  noball_runs  penalty_runs  \
# bowler
# ...

# %%
sns.scatterplot(x='total_runs',y='extra_runs', hue='noball_runs',data=bwdts)
# Out:
# <AxesSubplot:xlabel='total_runs', ylabel='extra_runs'>

# %%
mm=dm.drop_duplicates(subset='season',keep='last')

# %%
mm[['season','winner']].sort_values(by='season').reset_index(drop=True)
# Out:
#    season                 winner
# 0    2008       Rajasthan Royals
# 1    2009        Deccan Chargers
# 2    2010    Chennai Super Kings
# 3    2011    Chennai Super Kings
# 4    2012  Kolkata Knight Riders
# 5    2013         Mumbai Indians
# 6    2014  Kolkata Knight Riders
# 7    2015         Mumbai Indians
# 8    2016    Sunrisers Hyderabad
# 9    2017         Mumbai Indians

# %%
(dm['toss_winner'].value_counts()/(dm['team1'].value_counts()+ dm['team2'].value_counts()) *100).sort_values(ascending=False)
# Out:
# Deccan Chargers                57.333333
# Kochi Tuskers Kerala           57.142857
# Mumbai Indians                 54.140127
# Rajasthan Royals               53.389831
# Kolkata Knight Riders          52.702703
# Chennai Super Kings            50.381679
# Gujarat Lions                  50.000000
# Rising Pune Supergiants        50.000000
# Delhi Daredevils               48.979592
# Royal Challengers Bangalore    46.052632
# Sunrisers Hyderabad            46.052632
# Kings XI Punjab                45.945946
# Pune Warriors                  43.478261
# Rising Pune Supergiant         37.500000
# dtype: float64

# %%
dd['player_dismissed'].nunique()
# Out:
# 436

# %%
dd
# Out:
#         match_id  inning                 batting_team  \
# 0              1       1          Sunrisers Hyderabad
# 1              1       1          Sunrisers Hyderabad
# 2              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 4              1       1          Sunrisers Hyderabad
# ...          ...     ...                          ...
# 150455       636       2  Royal Challengers Bangalore
# 150456       636       2  Royal Challengers Bangalore
# 150457       636       2  Royal Challengers Bangalore
# 150458       636       2  Royal Challengers Bangalore
# 150459       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball        batsman    non_striker  \
# 0       Royal Challengers Bangalore     1     1      DA Warner       S Dhawan
# 1       Royal Challengers Bangalore     1     2      DA Warner       S Dhawan
# 2       Royal Challengers Bangalore     1     3      DA Warner       S Dhawan
# ...

# %% [markdown]
# # Most 4's hits by---> G Gambhir     484

# %%
dd[dd['batsman_runs']==4 ]['batsman'].value_counts()
# Out:
# G Gambhir     484
# SK Raina      402
# DA Warner     401
# S Dhawan      401
# V Kohli       384
#              ...
# UA Birla        1
# S Nadeem        1
# RR Raje         1
# AA Noffke       1
# GD McGrath      1
# Name: batsman, Length: 368, dtype: int64

# %% [markdown]
# # Most 6's hits by---> CH Gayle  266

# %%
dd[dd['batsman_runs']==6 ]['batsman'].value_counts()
# Out:
# CH Gayle         266
# SK Raina         174
# RG Sharma        173
# V Kohli          160
# DA Warner        160
#                 ...
# WD Parnell         1
# NL McCullum        1
# Sohail Tanvir      1
# BJ Haddin          1
# Iqbal Abdulla      1
# Name: batsman, Length: 301, dtype: int64

# %% [markdown]
# # Most ball played by---> V Kohli    3494

# %%
ball_played=dd['batsman'].value_counts() > 300
ppt=dd['batsman'].value_counts()
player=ppt[ball_played]
player
# Out:
# V Kohli          3494
# G Gambhir        3433
# SK Raina         3369
# RG Sharma        3274
# S Dhawan         3005
#                  ...
# KH Pandya         313
# S Sohal           311
# Azhar Mahmood     311
# JEC Franklin      309
# HH Pandya         306
# Name: batsman, Length: 114, dtype: int64

# %%
strike_rate=round((batsman_runs[ball_played]/player)*100,2).sort_values(ascending= False)

# %% [markdown]
# # Hightest Strike rate ---> AD Russell    164.00

# %%
strike_rate
# Out:
# AD Russell    164.00
# GJ Maxwell    157.56
# KH Pandya     153.35
# V Sehwag      148.83
# RR Pant       148.03
#                ...
# SC Ganguly    101.73
# CA Pujara      96.77
# UBT Chand      95.54
# A Mishra       89.01
# GH Vihari      86.69
# Length: 114, dtype: float64

# %%
no=dd[dd['bowler']=='Harbhajan Singh'][['noball_runs','wide_runs']].sum()[0]
wide=dd[dd['bowler']=='Harbhajan Singh'][['noball_runs','wide_runs']].sum()[1]

# %%
most_ball=dd[dd['bowler']=='Harbhajan Singh'].shape[0]-(no+wide)

# %%
most_over= most_ball/6

# %% [markdown]
# # Most over bowled  by---> Harbhajan Singh     483

# %%
most_over
# Out:
# 483.1666666666667

# %%
wicket=(dd[(dd['dismissal_kind'] == 'bowled') | (dd['dismissal_kind'] == 'lbw') | 
                 (dd['dismissal_kind'] == 'caught and bowled') | (dd['dismissal_kind'] == 'hit wicket') |
                 (dd['dismissal_kind'] == 'caught') | (dd['dismissal_kind'] == 'stumped')])

# %%
dd['dismissal_kind'].unique()
# Out:
# array([nan, 'caught', 'bowled', 'run out', 'lbw', 'caught and bowled',
#        'stumped', 'retired hurt', 'hit wicket', 'obstructing the field'],
#       dtype=object)

# %% [markdown]
# # Most wickets taken by ---> SL Malinga    154

# %%
wicket['bowler'].value_counts().sort_values(ascending=False)
# Out:
# SL Malinga         154
# A Mishra           134
# Harbhajan Singh    127
# PP Chawla          126
# DJ Bravo           122
#                   ...
# Swapnil Singh        1
# AM Rahane            1
# GH Vihari            1
# MK Tiwary            1
# S Vidyut             1
# Name: bowler, Length: 310, dtype: int64

# %% [markdown]
# # Hightest Run Scored  by ---> CH Gayle	175

# %%
dd.groupby(['match_id','batsman'])[['batsman_runs']].sum().sort_values(by='batsman_runs', ascending=False)
# Out:
#                          batsman_runs
# match_id batsman
# 411      CH Gayle                 175
# 60       BB McCullum              158
# 562      AB de Villiers           133
# 620      AB de Villiers           129
# 372      CH Gayle                 128
# ...                               ...
# 346      RE Levi                    0
#          CL White                   0
# 476      PP Chawla                  0
# 37       AF Milne                   0
# 604      DJ Bravo                   0
#
# [9515 rows x 1 columns]

# %%
dd.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')
