# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data= pd.read_csv('C:\\Users\\KIIT\\OneDrive\\Desktop\\code 1\\Machine_Learning\\house-pricing-data.csv')

# %%
data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
data.shape
# Out:
# (1460, 81)

# %%
data.sample(5)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1296  1297          20       RL         80.0     8700   Pave   NaN      Reg
# 1336  1337          90       RL         87.0     9246   Pave   NaN      IR1
# 181    182          70       RL         54.0     7588   Pave   NaN      Reg
# 720    721         120       RL          NaN     6563   Pave   NaN      IR1
# 747    748          70       RM         65.0    11700   Pave  Pave      IR1
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 1296         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1336         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 181          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 720          Low    AllPub  ...        0    NaN    NaN         NaN       0
# 747          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
col=data.columns

# %%
data.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.isnull().sum().sum()
# Out:
# 6965

# %%
sns.heatmap(data.corr())
# Out:
# <AxesSubplot:>

# %%
from ydata_profiling import ProfileReport
prof= ProfileReport(data)
prof.to_file('house.html')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5840\3530999724.py in <module>
# ----> 1 from ydata_profiling import ProfileReport
#       2 prof= ProfileReport(data)
#       3 prof.to_file('house.html')
#
# ModuleNotFoundError: No module named 'ydata_profiling'

# %%
c=0
Ncol=[]
for i in col:
    if data[i].isnull().sum() > 0:
        c+=1
        Ncol.append(i)
        p=(data[i].isnull().sum()/1460)*100
        print("{}    -->>   {}".format(i,data[i].isnull().sum()))
        print("{:.2f}%".format(p))
print(c)
# Out:
# LotFrontage    -->>   259
# 17.74%
# Alley    -->>   1369
# 93.77%
# MasVnrType    -->>   8
# 0.55%
# MasVnrArea    -->>   8
# 0.55%
# BsmtQual    -->>   37
# 2.53%
# BsmtCond    -->>   37
# 2.53%
# BsmtExposure    -->>   38
# 2.60%
# BsmtFinType1    -->>   37
# 2.53%
# BsmtFinType2    -->>   38
# 2.60%
# Electrical    -->>   1
# 0.07%
# FireplaceQu    -->>   690
# 47.26%
# GarageType    -->>   81
# 5.55%
# GarageYrBlt    -->>   81
# 5.55%
# GarageFinish    -->>   81
# 5.55%
# GarageQual    -->>   81
# 5.55%
# GarageCond    -->>   81
# 5.55%
# PoolQC    -->>   1453
# 99.52%
# Fence    -->>   1179
# 80.75%
# MiscFeature    -->>   1406
# 96.30%
# 19

# %%
data[Ncol].isnull().sum()
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType         8
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %%
data.drop(columns=['MiscFeature','Fence','PoolQC','Alley','FireplaceQu'],inplace=True)

# %%
data.shape
# Out:
# (1460, 76)

# %%
data.dropna(subset=['GarageType','GarageYrBlt','GarageCond','GarageQual','GarageFinish'],axis=0,inplace=True)

# %%
sns.countplot(x='GarageType',data= data)
# Out:
# <AxesSubplot:xlabel='GarageType', ylabel='count'>

# %%
for i in Ncol:
    sns.countplot(x=i,data= data)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5840\3981631063.py in <module>
#       1 for i in Ncol:
# ----> 2     sns.countplot(x=i,data= data)
#       3     plt.show()
#       4
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3596         raise ValueError("Cannot pass values for both `x` and `y`")
#    3597
# -> 3598     plotter = _CountPlotter(
#    3599         x, y, hue, data, order, hue_order,
#    3600         estimator, ci, n_boot, units, seed,
#
# ...

# %%
for i in Ncol:
    plt.pie(data[i].value_counts(),labels=data[i].value_counts().index)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Alley'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
data[['BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2']]
# Out:
#      BsmtQual BsmtCond BsmtExposure BsmtFinType1 BsmtFinType2
# 0          Gd       TA           No          GLQ          Unf
# 1          Gd       TA           Gd          ALQ          Unf
# 2          Gd       TA           Mn          GLQ          Unf
# 3          TA       Gd           No          ALQ          Unf
# 4          Gd       TA           Av          GLQ          Unf
# ...       ...      ...          ...          ...          ...
# 1455       Gd       TA           No          Unf          Unf
# 1456       Gd       TA           No          ALQ          Rec
# 1457       TA       Gd           No          GLQ          Unf
# 1458       TA       TA           Mn          GLQ          Rec
# 1459       TA       TA           No          BLQ          LwQ
#
# [1379 rows x 5 columns]

# %%
v=['BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2']
for i in v:
    print(i)
    print(data[i].value_counts())
    print('------------')
# Out:
# BsmtQual
# Gd    601
# TA    595
# Ex    121
# Fa     32
# Name: BsmtQual, dtype: int64
# ------------
# BsmtCond
# TA    1247
# Gd      63
# Fa      38
# Po       1
# Name: BsmtCond, dtype: int64
# ------------
# BsmtExposure
# No    896
# Av    213
# Gd    128
# Mn    111
# Name: BsmtExposure, dtype: int64
# ------------
# BsmtFinType1
# GLQ    408
# Unf    396
# ALQ    209
# BLQ    141
# Rec    126
# LwQ     69
# Name: BsmtFinType1, dtype: int64
# ------------
# BsmtFinType2
# Unf    1186
# Rec      53
# LwQ      46
# BLQ      32
# ALQ      19
# GLQ      12
# Name: BsmtFinType2, dtype: int64
# ------------

# %%
data['BsmtFinType2'].fillna('Unf',inplace=True)

# %%
data['BsmtExposure'].fillna('No',inplace=True)

# %%
data['BsmtCond'].fillna('TA',inplace=True)

# %%
data['BsmtFinType1'].fillna('GLQ',inplace=True)

# %%
data['BsmtQual'].fillna('Gd',inplace=True)

# %%
v=['Electrical','MasVnrArea','MasVnrType','LotFrontage']
for i in v:
    print(i)
    print(data[i].value_counts())
    print('------------')
# Out:
# Electrical
# SBrkr    1272
# FuseA      81
# FuseF      22
# FuseP       2
# Mix         1
# Name: Electrical, dtype: int64
# ------------
# MasVnrArea
# 0.0      786
# 72.0       8
# 108.0      8
# 180.0      8
# 16.0       7
#         ...
# 562.0      1
# 89.0       1
# 921.0      1
# 762.0      1
# 119.0      1
# Name: MasVnrArea, Length: 327, dtype: int64
# ------------
# MasVnrType
# None       789
# BrkFace    439
# Stone      128
# BrkCmn      15
# Name: MasVnrType, dtype: int64
# ------------
# LotFrontage
# 60.0     130
# 80.0      68
# 70.0      65
# 75.0      52
# 50.0      50
#         ...
# 150.0      1
# 141.0      1
# 140.0      1
# 112.0      1
# 46.0       1
# Name: LotFrontage, Length: 107, dtype: int64
# ------------

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
data['MasVnrType'].fillna('None',inplace=True)

# %%
data['MasVnrArea'].fillna(0.0,inplace=True)

# %%
data['Electrical'].fillna('SBrkr',inplace=True)

# %%
data['LotFrontage'].fillna(data['LotFrontage'].mean(),inplace=True)

# %%
cols_list=[]
for i in data.columns:
    if data[i].dtype== 'int64':
        cols_list.append(i)

# %%
len(cols_list)
# Out:
# 35

# %%
for i in cols_list:
    sns.boxplot(x=i,data=data)

# %%
sns.distplot(data['SalePrice'])
# Out:
# C:\Users\KIIT\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='SalePrice', ylabel='Density'>

# %%
sdt=data['SalePrice'].std()

# %%
m=data['SalePrice'].mean()

# %%
mean=[]
for i in data['SalePrice']:
    mean.append((i-m)/sdt)

# %%
sns.distplot(mean)
# Out:
# C:\Users\KIIT\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
sns.distplot(data['SalePrice']);
# Out:
# C:\Users\KIIT\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data['SalePrice'].skew()
# Out:
# 1.935362098363132

# %%
data['SalePrice'].kurt()
# Out:
# 6.735649337267559
